# %% [markdown]
# ## WORKSHOP 3-Canny Edge Detection
#
# ### NAME : A PRAVEEN KISHORE
# ### REG. NO : 212225220074

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('myimage.png',cv2.IMREAD_GRAYSCALE)

# %%
import cv2

# Check if img loaded properly before running operations
img = cv2.imread("myimage.png")

if img is None:
    raise FileNotFoundError("Could not load image. Check the file path.")

blurred = cv2.GaussianBlur(img, (5, 5), 0)

# %%
blurred =cv2.GaussianBlur(img, (5,5),0)

# %%
edges = cv2.Canny(blurred, 50, 150)

# %%
plt.figure(figsize=(10,5))
plt.subplot(121),plt.imshow(img, cmap='gray')
plt.title('Original Image'), plt.axis('off')
plt.subplot(122),plt.imshow(edges, cmap='gray')
plt.title('Detected Edges'), plt.axis('off')
plt.show()
